# %% [markdown]
# #####Cloning the repo#####

# %%
# !git clone https://github.com/WongKinYiu/yolov7
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1185, done.
# remote: Total 1185 (delta 0), reused 0 (delta 0), pack-reused 1185
# Receiving objects: 100% (1185/1185), 74.22 MiB | 16.55 MiB/s, done.
# Resolving deltas: 100% (511/511), done.

# %% [markdown]
# ###training the model not necessary###

# %%
# !unrar x -Y /content/nrw1.rar /content/
# %cd /content/yolov7
# Out:
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from /content/nrw1.rar
#
#   OK
#   OK
# All OK
# /content/yolov7

# %% [markdown]
# ### detection

# %%
# !python detect.py --weights yolov7.pt --conf 0.25 --img-size 640 --source /content/draj1.mp4
# Out:
# Namespace(weights=['yolov7.pt'], source='/content/draj1.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# ### firebase connection

# %%
# !pip install pyrebase4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.4/454.4 kB 29.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 66.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.4/86.4 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for gcloud: filename=gcloud-0.18.3-py3-none-any.whl size=602934 sha256=33fc2c2d671e73bacf728f37e1f84bde1abc3d0d25c107c2ca915c884c902733
#   Stored in directory: /root/.cache/pip/wheels/7c/30/88/5017af921da3a33af785f0d0fd3e944b845bc62a445a2c2f69
# ...
#   Created wheel for jwcrypto: filename=jwcrypto-1.5.0-py3-none-any.whl size=91730 sha256=a3c1ec003ec8494cf2daa9b895c2d02d228afd2993fd8298588af219e423a9d0
# ...

# %%
import pyrebase
firebaseConfig={
     "apiKey": "AIzaSyAR7Hrs-GJPB2mQ_ycBBx1iP78THeQzLO8",
  "authDomain": "esp32-dht11-4833b.firebaseapp.com",
  "databaseURL": "https://esp32-dht11-4833b-default-rtdb.firebaseio.com",
  "projectId": "esp32-dht11-4833b",
  "storageBucket": "esp32-dht11-4833b.appspot.com",
  "messagingSenderId": "349487023088",
  "appId": "1:349487023088:web:1fbc373fe2d066cb0d9335",
 " measurementId": "G-28W8T1MN18"
}
firebase= pyrebase.initialize_app(firebaseConfig)
db=firebase.database()
storage=firebase.storage()
data={"n":"aloalo"}
db.child("nrw").push(data)
# Out:
# {'name': '-NYikZkMvx8-xfqVYWZT'}
